# %% [markdown]
# # Машинное обучение. Практическая работа

# %% [markdown]
# В этой практической работе четыре обязательные задачи.
#
# Они помогут понять, что вы действительно усвоили материал модуля.
#
#
# Удачи!

# %% [markdown]
# ## Цели практической работы
#
# Научиться:
# - обучать модели, основанные на деревьях решений;
# - научиться оценивать и увеличивать их качество.

# %% [markdown]
# ## Что входит в практическую работу
#
# 1. Загрузите датасет и ознакомьтесь с ним.
# 2. Подготовьте базовую модель дерева решений и измерьте её качество.
# 3. Подготовьте базовую модель случайного леса и измерьте её качество.
# 4. Увеличьте точность модели случайного леса на тестовых данных.
# 5. Проведите анализ влияния признаков на модель.

# %% [markdown]
# ## Что оценивается
#
# * Выполнены все четыре задачи. Для каждой:
#  * в коде нет ручных перечислений, все действия автоматизированы;
#  * результаты вычислений и применённых операций корректны;
#  * ответы на вопросы, где требуется, корректны и обоснованы;
#  * код читабелен: переменным даны осмысленные названия, соблюдены отступы и правила расстановки пробелов; стилизация кода соответствует рекомендациям [PEP 8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html).
#
# * Репозиторий проекта оформлен корректно:
#  * содержит осмысленные коммиты, содержащие конкретные реализованные фичи;
#  * ветки названы согласно назначению;
#  * файлы, не связанные с проектом, не хранятся в репозитории.

# %% [markdown]
# ## Как отправить работу на проверку
#
# Сдайте практическую работу этого модуля через систему контроля версий Git сервиса Skillbox GitLab. После загрузки работы на проверку напишите об этом в личном кабинете своему куратору.

# %% [markdown]
# ## Обязательные задачи

# %% [markdown]
# ### Описание датасета:
# - `id`— идентификатор записи;
# - `is_manufacturer_name`— признак производителя автомобиля;
#
# - `region_*`— регион;
# - `x0_*`— тип топлива;
# - `manufacturer_*`— производитель;
# - `short_model_*`— сокращённая модель автомобиля;
# - `title_status_*`— статус;
# - `transmission_*`— коробка передач;
# - `state_*`— штат;
# - `age_category_*`— возрастная категория автомобиля;
#
# - `std_scaled_odometer`— количество пройденных миль (после стандартизации);
# - `year_std`— год выпуска (после стандартизации);
# - `lat_std`— широта (после стандартизации);
# - `long_std`— долгота (после стандартизации);
# - `odometer/price_std`— отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`— количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`— количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`— длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`— количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`— номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`— день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`— количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
#
# - `price`— стоимость;
# - `price_category`— категория цены.

# %% [markdown]
# 1. Подготовка базовой модели
#
# Обучите простую модель классификации с помощью DecisionTreeClassifier на данных из датасета vehicles_dataset_prepared.csv. Для этого сделайте шаги:
#
# 1. Обучите модель дерева решений с зафиксированным random_state на тренировочной выборке.
# 2. Сделайте предикт на тестовой выборке.
# 3. Замерьте точность на тестовой выборке и выведите матрицу ошибок.
# 4. Удалите фичи с нулевыми весами по feature_importance из тренировочной и тестовой выборок.
# 5. Заново обучите модель и измерьте качество.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('data/vehicles_dataset_prepared.csv')

df_prepared = df.copy()
df_prepared = df_prepared.drop(['price', 'odometer/price_std'], axis=1)

x = df_prepared.drop(['price_category'], axis=1)
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

# %%
# Ваш код здесь 
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_test, predicted_test))
# Out:
# 0.6708246708246708

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[732,  51, 214],
#        [ 42, 690, 221],
#        [185, 237, 514]], dtype=int64)

# %%
clf.feature_importances_
# Out:
# array([0.03238681, 0.00041354, 0.00260591, ..., 0.00218235, 0.01516176,
#        0.04469698])

# %%
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)
f_imp_list
# Out:
# [('age_category_new', 0.1751319079983745),
#  ('std_scaled_odometer', 0.08071446597801363),
#  ('model_len_std', 0.07488167716969586),
#  ('desc_len_std', 0.07109303478897128),
#  ('diff_years_std', 0.04469697944027492),
#  ('lat_std', 0.041653172958734),
#  ('long_std', 0.03811971107798329),
#  ('x0_diesel', 0.033097961449185156),
#  ('id', 0.03238680672609698),
#  ('year_std', 0.02243809913077893),
#  ('dayofweek_std', 0.015161761383772267),
#  ('short_model_wrangler', 0.009446703472159207),
#  ('manufacturer_ram', 0.009366705896006494),
#  ('manufacturer_kia', 0.009160285070398509),
#  ('model_word_count_std', 0.0071565810797468805),
#  ('manufacturer_hyundai', 0.006042876609772032),
#  ('short_model_f-150', 0.005902540401110402),
#  ('manufacturer_gmc', 0.0052456665878841055),
#  ('short_model_silverado', 0.00515797153304299),
#  ('model_in_desc_std', 0.004961107435345975),
#  ('short_model_Scion', 0.004865746378858322),
#  ('manufacturer_mercedes-benz', 0.004614266590743073),
#  ('manufacturer_volkswagen', 0.0042539634460957085),
#  ('is_chevrolet', 0.0037609998750090337),
#  ('manufacturer_bmw', 0.0037308943901749087),
#  ('manufacturer_chevrolet', 0.003636303396927669),
#  ('short_model_tacoma', 0.0033983475702303164),
#  ('manufacturer_ford', 0.003311646086999768),
#  ('short_model_f150', 0.003123475760770655),
#  ('transmission_automatic', 0.0031172797807006705),
#  ('short_model_f-250', 0.003072061282574861),
#  ('manufacturer_rover', 0.003001919076076054),
#  ('state_ny', 0.0028742253999328895),
#  ('manufacturer_dodge', 0.002845347605657755),
#  ('short_model_4runner', 0.0028271666378600732),
#  ('short_model_sierra', 0.002741311715556527),
#  ('short_model_jetta', 0.0026803994385185942),
#  ('state_il', 0.0026660638316391588),
#  ('short_model_escape', 0.002646034668149088),
#  ('is_ford', 0.0026059062872931986),
#  ('short_model_focus', 0.002545024259441115),
#  ('manufacturer_honda', 0.0025369160872666307),
#  ('short_model_corolla', 0.0025261597292817605),
#  ('title_status_rebuilt', 0.0024698100463897495),
#  ('title_status_clean', 0.002435425658426848),
#  ('short_model_mustang', 0.0023821926115094347),
#  ('manufacturer_cadillac', 0.0023529396259085863),
#  ('manufacturer_nissan', 0.0023224448347121483),
#  ('short_model_spark', 0.0023032469401461286),
#  ('short_model_camry', 0.0022662633314930276),
#  ('manufacturer_mitsubishi', 0.002255834820129204),
#  ('state_nj', 0.002254779189459798),
#  ('month_std', 0.00218234739668507),
#  ('short_model_tahoe', 0.0021510649728907314),
#  ('short_model_cruze', 0.002142596747455349),
#  ('short_model_sentra', 0.0020722547929349177),
#  ('region_flint', 0.0019382956795931273),
#  ('short_model_tundra', 0.0019329740984167568),
#  ('state_oh', 0.0018930338025656612),
#  ('region_tucson', 0.0018595876290719436),
#  ('manufacturer_toyota', 0.0018361013155822874),
#  ('short_model_x5', 0.0018321608846169628),
#  ('manufacturer_lexus', 0.0018128265283355546),
#  ('state_nm', 0.0017611670575117182),
#  ('x0_hybrid', 0.0017076362627740432),
#  ('x0_gas', 0.0016959754804880668),
#  ('short_model_fj', 0.001669725207062581),
#  ('manufacturer_buick', 0.0016361770743272364),
#  ('state_id', 0.001583057491514315),
#  ('short_model_versa', 0.0015732643373993558),
#  ('manufacturer_jeep', 0.0015634030055737273),
#  ('short_model_colorado', 0.0015605408603308441),
#  ('state_ky', 0.001556007903096735),
#  ('short_model_trax', 0.0015123619583742927),
#  ('short_model_altima', 0.0015050695744362142),
#  ('short_model_sonic', 0.0014991615123911542),
#  ('title_status_lien', 0.0014809432988255173),
#  ('short_model_titan', 0.0014385165729997585),
#  ('is_toyota', 0.0014363117555625516),
#  ('short_model_elantra', 0.0014213907381493017),
#  ('state_fl', 0.0014111368654261486),
#  ('short_model_corvette', 0.0013859287947347522),
#  ('state_tx', 0.0013607137141876688),
#  ('short_model_cooper', 0.001336877820624254),
#  ('region_san antonio', 0.0013343843267129237),
#  ('short_model_f250', 0.0013326527859747106),
#  ('state_mi', 0.0012893991350545907),
#  ('short_model_g', 0.0012870956168290464),
#  ('region_lakeland', 0.0012643888226523078),
#  ('state_co', 0.0012485009684586434),
#  ('region_raleigh / durham / CH', 0.0012481306339894515),
#  ('region_orlando', 0.0012438178504455785),
#  ('region_lansing', 0.0012013788847525804),
#  ('state_in', 0.0011908017852273543),
#  ('short_model_m3', 0.0011594085871457788),
#  ('state_mn', 0.0011557618803070477),
#  ('short_model_fit', 0.0011553764588166883),
#  ('region_south florida', 0.001144038561760081),
#  ('transmission_manual', 0.0011428910319223327),
#  ('short_model_golf', 0.001126259759957802),
#  ('short_model_other', 0.0011203445558882184),
#  ('region_detroit metro', 0.0011186219820765624),
#  ('short_model_f-350', 0.0011081106692366364),
#  ('state_nc', 0.0010971408861317157),
#  ('state_ms', 0.0010752967078554746),
#  ('short_model_avalanche', 0.0010712742846942895),
#  ('short_model_super', 0.0010666018744709342),
#  ('short_model_mazda3', 0.0010649553639631292),
#  ('manufacturer_other', 0.0010562759460308057),
#  ('region_chicago', 0.0010488166544467858),
#  ('x0_electric', 0.0010483868385354183),
#  ('region_dallas / fort worth', 0.0010422974951364557),
#  ('manufacturer_chrysler', 0.0010038636393728416),
#  ('short_model_malibu', 0.0010031231927783964),
#  ('short_model_transit', 0.0009998416828418157),
#  ('manufacturer_subaru', 0.0009789793701027838),
#  ('x0_other', 0.0009696634498010494),
#  ('short_model_express', 0.0009625312967217121),
#  ('state_ct', 0.00095876334387633),
#  ('short_model_odyssey', 0.0009460789203822285),
#  ('manufacturer_mazda', 0.0009318961287109399),
#  ('state_wi', 0.0009311084737254842),
#  ('short_model_land', 0.0009212520626853584),
#  ('state_ca', 0.0009209404382213909),
#  ('short_model_promaster', 0.000917131843894454),
#  ('short_model_regal', 0.0009109950734567811),
#  ('state_md', 0.000895988076507322),
#  ('region_little rock', 0.0008879845740374654),
#  ('region_omaha / council bluffs', 0.0008517081017987164),
#  ('short_model_tiguan', 0.0008492549495225715),
#  ('short_model_renegade', 0.0008481713427091601),
#  ('short_model_edge', 0.0008421733176567862),
#  ('short_model_f650', 0.0008395216748567141),
#  ('short_model_sportage', 0.0008350683764970415),
#  ("region_spokane / coeur d'alene", 0.0008281218133616706),
#  ('short_model_500', 0.0008269082904487314),
#  ('region_worcester / central MA', 0.0008211263521023693),
#  ('short_model_impala', 0.0008204607919080751),
#  ('state_mt', 0.0008112425416459783),
#  ('region_SF bay area', 0.0008075515675254751),
#  ('region_palm springs', 0.0008044011777625877),
#  ('short_model_mdx', 0.0008041648359896098),
#  ('short_model_camaro', 0.0007981642662924452),
#  ('short_model_mirage', 0.0007977968752280337),
#  ('region_southwest michigan', 0.0007935098003350696),
#  ('region_roanoke', 0.0007797937365419203),
#  ('region_portland', 0.0007792640345983241),
#  ('state_tn', 0.0007743196036534425),
#  ('short_model_gx', 0.0007741382276692169),
#  ('age_category_old', 0.0007734144222746357),
#  ('short_model_grand', 0.0007709993686779015),
#  ('region_philadelphia', 0.0007698492860091555),
#  ('region_nashville', 0.0007686680662039168),
#  ('region_modesto', 0.0007643470901957862),
#  ('short_model_mkz', 0.0007612575336372995),
#  ('region_yakima', 0.0007534746255030679),
#  ('region_reno / tahoe', 0.0007489431704846444),
#  ('transmission_other', 0.0007469378669445371),
#  ('region_columbus', 0.0007466650125706813),
#  ('manufacturer_volvo', 0.0007462201625148056),
#  ('short_model_fusion', 0.0007452011049057701),
#  ('short_model_town', 0.0007427980664340525),
#  ('region_minneapolis / st paul', 0.0007405469998169804),
#  ('manufacturer_acura', 0.0007388594101201041),
#  ('short_model_1500', 0.0007374811437909025),
#  ('region_new hampshire', 0.0007364095687762856),
#  ('short_model_maxima', 0.0007300691756985482),
#  ('region_jacksonville', 0.0007244956730621583),
#  ('region_vermont', 0.0007241265542466581),
#  ('short_model_e-series', 0.0007143332365473656),
#  ('short_model_challenger', 0.0007129861457197863),
#  ('short_model_e-350', 0.0007127535996839997),
#  ('region_kansas city, MO', 0.0007124298206997197),
#  ('short_model_cr-v', 0.0006953960269931469),
#  ('short_model_a4', 0.0006830131418260612),
#  ('short_model_rx', 0.0006786696263304665),
#  ('short_model_pilot', 0.0006684245116122998),
#  ('short_model_PROGRAMS', 0.0006581410575874951),
#  ('state_pa', 0.0006535706335764707),
#  ('region_rochester', 0.0006507416086227296),
#  ('region_ventura county', 0.0006489177671155222),
#  ('region_des moines', 0.0006486881088517313),
#  ('short_model_rogue', 0.0006450056705553873),
#  ('title_status_salvage', 0.000634381573941951),
#  ('state_ia', 0.0006320829847673604),
#  ('region_fort collins / north CO', 0.0006237978728096294),
#  ('state_az', 0.0006206799036399927),
#  ('region_norfolk / hampton roads', 0.0006147686664624692),
#  ('short_model_f-250sd', 0.0006139008617778531),
#  ('region_oklahoma city', 0.0006112344933907284),
#  ('region_memphis', 0.0005853778298665295),
#  ('region_wenatchee', 0.0005730823617133187),
#  ('region_knoxville', 0.0005519566042859145),
#  ('region_colorado springs', 0.0005514502220801468),
#  ('short_model_hummer', 0.0005345375202333474),
#  ('region_fresno / madera', 0.0005293788112017209),
#  ('region_tulsa', 0.0005223613775933157),
#  ('manufacturer_lincoln', 0.0005037743820617101),
#  ('short_model_escalade', 0.0005005935323035722),
#  ('region_charlotte', 0.0004918335011892985),
#  ('region_redding', 0.00048118705843738676),
#  ('state_ok', 0.00047180198426085066),
#  ('short_model_gla-class', 0.0004510634355021308),
#  ('region_boise', 0.0004510175039070912),
#  ('short_model_santa', 0.0004409256427477633),
#  ('region_saginaw-midland-baycity', 0.0004407194582059117),
#  ('short_model_civic', 0.00044064620817264687),
#  ('short_model_charger', 0.0004372084855828874),
#  ('short_model_sienna', 0.00043500642819213137),
#  ('region_la crosse', 0.0004342231145531336),
#  ('region_missoula', 0.00043400010909203855),
#  ('short_model_x6', 0.0004335726561809516),
#  ('region_santa fe / taos', 0.0004335726561809516),
#  ('region_southern illinois', 0.00043253345502062895),
#  ('region_birmingham', 0.0004321128155877491),
#  ('region_visalia-tulare', 0.0004305718520500224),
#  ('short_model_i3', 0.0004304960735477171),
#  ('short_model_plymouth', 0.0004293803948929759),
#  ('region_maine', 0.0004293803948929759),
#  ('short_model_excursion', 0.00042918080010003736),
#  ('short_model_e-golf', 0.00042821637729917246),
#  ('short_model_yaris', 0.0004266125706426156),
#  ('short_model_qx80', 0.00042554659746920254),
#  ('short_model_CLICK', 0.00042531168315046913),
#  ('state_me', 0.00042501775729442815),
#  ('short_model_eurovan', 0.00042476644790730904),
#  ('state_sd', 0.00042439651530939683),
#  ('region_lawrence', 0.00042343187014034817),
#  ('region_battle creek', 0.000422837842540541),
#  ('short_model_k900', 0.00042216284943934743),
#  ('region_akron / canton', 0.00042216284943934743),
#  ('short_model_lx450', 0.00042211523055373445),
#  ('short_model_s-class', 0.00042064697289007346),
#  ('short_model_c-hr', 0.00041995225357931094),
#  ('region_prescott', 0.000419061244831221),
#  ('short_model_genesis', 0.0004190338793533867),
#  ('short_model_gto', 0.0004190338793533867),
#  ('region_tuscaloosa', 0.000418137908671631),
#  ('short_model_325is', 0.0004178940782481988),
#  ('short_model_3-series', 0.0004177653197576874),
#  ('short_model_g37', 0.00041681747156262244),
#  ('region_olympic peninsula', 0.00041633264496299143),
#  ('short_model_AM', 0.00041590858500320884),
#  ('short_model_1968', 0.0004137866024266619),
#  ('region_billings', 0.0004137866024266619),
#  ('region_yuba-sutter', 0.0004137866024266619),
#  ('is_audi', 0.0004135369574176561),
#  ('region_corpus christi', 0.00041208435266745444),
#  ('short_model_nova', 0.0004119062569999708),
#  ('short_model_eos', 0.0004113381609921843),
#  ('short_model_sedona', 0.0004113381609921843),
#  ('short_model_sport', 0.0004113381609921843),
#  ('region_amarillo', 0.00041070972769066824),
#  ('short_model_m35s', 0.000409056882225924),
#  ('region_lexington', 0.000409056882225924),
#  ('short_model_q7', 0.0004085862507601947),
#  ('short_model_durango', 0.0004084816459852943),
#  ('region_south dakota', 0.0004084816459852943),
#  ('short_model_mkx', 0.00040790075517844283),
#  ('short_model_avalon', 0.00040779512221052894),
#  ('short_model_cx-5', 0.0004075129148090438),
#  ('region_southern maryland', 0.00040663553781284577),
#  ('short_model_Chevorlet', 0.000406070302148309),
#  ('region_clarksville', 0.0004057059213018321),
#  ('region_danville', 0.00040510576461351503),
#  ('manufacturer_porsche', 0.0004047702972470453),
#  ('short_model_forte', 0.00040470065884890075),
#  ('region_savannah / hinesville', 0.0004037805455301814),
#  ('region_madison', 0.0004026182730764139),
#  ('region_laredo', 0.0004015669096582711),
#  ('region_boulder', 0.00040105470696738),
#  ('short_model_outlander', 0.00040092841041345945),
#  ('short_model_evoque', 0.0004004166880450356),
#  ('short_model_e450', 0.0003994320144088439),
#  ('region_abilene', 0.0003986425387393399),
#  ('region_fredericksburg', 0.0003977238373472234),
#  ('state_de', 0.00039668678441625086),
#  ('short_model_2500', 0.0003961034142887702),
#  ('region_tallahassee', 0.0003961034142887702),
#  ('manufacturer_jaguar', 0.0003961034142887702),
#  ('region_los angeles', 0.0003956203613445154),
#  ('region_st cloud', 0.0003951131557530468),
#  ('region_buffalo', 0.0003948846345524969),
#  ('region_youngstown', 0.00039196258601439634),
#  ('short_model_HUMMER', 0.0003914403818003544),
#  ('region_texarkana', 0.0003912164241124802),
#  ('region_western slope', 0.0003901428977946836),
#  ('short_model_e350', 0.0003898481177957936),
#  ('short_model_dart', 0.00038890861217279513),
#  ('manufacturer_audi', 0.0003883228115080978),
#  ('short_model_328xi', 0.0003882503682906916),
#  ('short_model_xc90', 0.0003876173069916691),
#  ('short_model_verano', 0.0003841367664749593),
#  ('short_model_1966', 0.00038346458824074065),
#  ('short_model_cobalt', 0.0003819568637784571),
#  ('region_eugene', 0.0003819568637784571),
#  ('short_model_sorento', 0.00038117409554653154),
#  ('region_san diego', 0.00038110296699695926),
#  ('region_houston', 0.00037994656449541253),
#  ('state_nv', 0.00037994656449541253),
#  ('short_model_428', 0.000379706749706123),
#  ('short_model_taurus', 0.0003792433044816493),
#  ('region_florida keys', 0.00037748953203835804),
#  ('short_model_lr4', 0.00037251104792047424),
#  ('region_scottsbluff / panhandle', 0.0003720359062777189),
#  ('short_model_isf', 0.00037181258970562375),
#  ('short_model_lacrosse', 0.0003713469508957221),
#  ('region_corvallis/albany', 0.0003713469508957221),
#  ('region_williamsport', 0.0003713469508957221),
#  ('short_model_explorer', 0.0003711187807262),
#  ('region_rapid city / west SD', 0.0003704981578651023),
#  ('region_anchorage / mat-su', 0.0003702043448929669),
#  ('region_zanesville / cambridge', 0.0003697327845459976),
#  ('short_model_rav4', 0.00036638157203594974),
#  ('region_gold country', 0.0003661803846223917),
#  ('region_scranton / wilkes-barre', 0.00036563392088194207),
#  ('short_model_juke', 0.00036511112473917206),
#  ('short_model_BUY', 0.0003641011567319029),
#  ('region_wausau', 0.0003605755828169443),
#  ('short_model_accord', 0.00035649307285989313),
#  ('short_model_equinox', 0.00035649307285989313),
#  ('state_ma', 0.00035649307285989313),
#  ('short_model_nitro', 0.0003560087072717685),
#  ('short_model_freestyle', 0.00035277960335093595),
#  ('region_eastern NC', 0.00035214559636160154),
#  ('short_model_f-type', 0.00035211764648347075),
#  ('region_inland empire', 0.00034598029298242225),
#  ('short_model_380sl', 0.000343034681107466),
#  ('short_model_ilx', 0.0003364770226184638),
#  ('short_model_SL', 0.0003342122558061499),
#  ('short_model_is250', 0.0003342122558061499),
#  ('short_model_liberty', 0.0003342122558061499),
#  ('state_al', 0.0003342122558061499),
#  ('state_va', 0.0003342122558061499),
#  ('short_model_enclave', 0.0003292203787613211),
#  ('state_ne', 0.0003292203787613211),
#  ('region_susanville', 0.00032679809981580617),
#  ('short_model_es', 0.0002970775607165777),
#  ('short_model_murano', 0.0002970775607165777),
#  ('region_albany', 0.0002970775607165777),
#  ('region_central michigan', 0.0002970775607165777),
#  ('region_north mississippi', 0.0002970775607165777),
#  ('region_tampa bay area', 0.0002970775607165777),
#  ('state_ga', 0.0002970775607165777),
#  ('state_or', 0.0002970775607165777),
#  ('region_santa barbara', 0.000294425082495894),
#  ('short_model_fiesta', 0.0002864676478338427),
#  ('short_model_encore', 0.00024113493199823583),
#  ('short_model_xv', 0.00022280817053743325),
#  ('region_asheville', 0.00022280817053743325),
#  ('region_chico', 0.00022280817053743325),
#  ('region_green bay', 0.00022280817053743325),
#  ('region_monterey bay', 0.00022280817053743325),
#  ('region_victoria', 0.00022280817053743325),
#  ('state_wa', 0.00022280817053743325),
#  ('short_model_leaf', 0.00022193952269908052),
#  ('short_model_highlander', 0.00021852339802709884),
#  ('short_model_prius', 0.00021851192390342773),
#  ('region_pueblo', 0.00021579707356979709),
#  ('region_kalispell', 0.00021175852611728796),
#  ('region_salem', 0.0002073244862539514),
#  ('region_bend', 0.00020424082299264743),
#  ('region_phoenix', 0.00014616848067171867),
#  ('region_sacramento', 0.00014210625337360538),
#  ('region_st louis, MO', 0.00010775149230908806),
#  ('region_central NJ', 8.599754833790955e-05),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_198.5', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_200', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2002', 0.0),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3', 0.0),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_300zx', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328d', 0.0),
#  ('short_model_328i', 0.0),
#  ('short_model_330i', 0.0),
#  ('short_model_330xi', 0.0),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_640', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_650xi', 0.0),
#  ('short_model_7', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750i', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AMC', 0.0),
#  ('short_model_ASC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_F250', 0.0),
#  ('short_model_FORD*', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_Flexible', 0.0),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMC,', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_IC', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_Peterbilt', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_Plymouth', 0.0),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Town', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_Xx', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a5', 0.0),
#  ('short_model_a6', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_a8', 0.0),
#  ('short_model_acadia', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_atlas', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avanger', 0.0),
#  ('short_model_avenger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_bronco', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_bus', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c-max', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_canyon', 0.0),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayenne', 0.0),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc', 0.0),
#  ('short_model_cc300', 0.0),
#  ('short_model_cc4500', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_cherokee', 0.0),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_corsair', 0.0),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_coupe', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crosstrek', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cube', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_davidson', 0.0),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durangon', 0.0),
#  ('short_model_e', 0.0),
#  ('short_model_e-150', 0.0),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-450', 0.0),
#  ('short_model_e-class', 0.0),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e150', 0.0),
#  ('short_model_e250', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_ecosport', 0.0),
#  ('short_model_el', 0.0),
#  ('short_model_elcamino', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_expedition', 0.0),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f350', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f550', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f700', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_firebird', 0.0),
#  ('short_model_five', 0.0),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freightliner', 0.0),
#  ('short_model_frontier', 0.0),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g6', 0.0),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_gr', 0.0),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs350', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_impreza', 0.0),
#  ('short_model_insight', 0.0),
#  ('short_model_international', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_isuzu', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lancer', 0.0),
#  ('short_model_landcruiser', 0.0),
#  ('short_model_legacy', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_lightning', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_ls', 0.0),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m35', 0.0),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_ml', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_model', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_mx-5', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nv', 0.0),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_outback', 0.0),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passat', 0.0),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_patriot', 0.0),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prizm', 0.0),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q5', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx50', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_ranger', 0.0),
#  ('short_model_rat', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rio', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ('short_model_roadster', 0.0),
#  ('short_model_romeo', 0.0),
#  ('short_model_rondo', 0.0),
#  ('short_model_rouge', 0.0),
#  ('short_model_routan', 0.0),
#  ('short_model_rs', 0.0),
#  ('short_model_rsx', 0.0),
#  ('short_model_rx-8', 0.0),
#  ('short_model_rx300', 0.0),
#  ('short_model_rx330', 0.0),
#  ('short_model_rx350', 0.0),
#  ('short_model_rx400h', 0.0),
#  ('short_model_rx7', 0.0),
#  ('short_model_rx8', 0.0),
#  ('short_model_s', 0.0),
#  ('short_model_s-10', 0.0),
#  ...]

# %%
to_drop_f_imp_list = []
for i in f_imp_list:
    if i[1] == 0:
        to_drop_f_imp_list.append(i[0])
to_drop_f_imp_list
# Out:
# ['short_model_-benz',
#  'short_model_1',
#  'short_model_124',
#  'short_model_128i',
#  'short_model_135i',
#  'short_model_163869',
#  'short_model_1928',
#  'short_model_1951',
#  'short_model_1954',
#  'short_model_1960s',
#  'short_model_1972',
#  'short_model_1977',
#  'short_model_1978',
#  'short_model_198.5',
#  'short_model_1988',
#  'short_model_1994',
#  'short_model_1999',
#  'short_model_2',
#  'short_model_200',
#  'short_model_2000',
#  'short_model_2002',
#  'short_model_2006',
#  'short_model_2007',
#  'short_model_2008',
#  'short_model_2009',
#  'short_model_2012',
#  'short_model_2015',
#  'short_model_2016',
#  'short_model_2017',
#  'short_model_2018',
#  'short_model_210',
#  'short_model_240',
#  'short_model_2500hd',
#  'short_model_280zx',
#  'short_model_3',
#  'short_model_3-window',
#  'short_model_3.2',
#  'short_model_300',
#  'short_model_300-series',
#  'short_model_300c',
#  'short_model_300s',
#  'short_model_300zx',
#  'short_model_3100',
#  'short_model_318i',
#  'short_model_320i',
#  'short_model_323i',
#  'short_model_325ci',
#  'short_model_325i',
#  'short_model_325xi',
#  'short_model_328',
#  'short_model_328ci',
#  'short_model_328d',
#  'short_model_328i',
#  'short_model_330i',
#  'short_model_330xi',
#  'short_model_335i',
#  'short_model_335xi',
#  'short_model_350',
#  'short_model_3500',
#  'short_model_3500hd',
#  'short_model_350z',
#  'short_model_370z',
#  'short_model_3i',
#  'short_model_4',
#  'short_model_4-runner',
#  'short_model_430i',
#  'short_model_435i',
#  'short_model_440xi',
#  'short_model_4500',
#  'short_model_4x4',
#  'short_model_5',
#  'short_model_5-series',
#  'short_model_50',
#  'short_model_500c',
#  'short_model_500l',
#  'short_model_500x',
#  'short_model_525i',
#  'short_model_528i',
#  'short_model_528xi',
#  'short_model_530',
#  'short_model_530i',
#  'short_model_535i',
#  'short_model_535xi',
#  'short_model_540i',
#  'short_model_545i',
#  'short_model_5500',
#  'short_model_5500hd',
#  'short_model_550i',
#  'short_model_5th',
#  'short_model_6',
#  'short_model_640',
#  'short_model_645ci',
#  'short_model_650i',
#  'short_model_650xi',
#  'short_model_7',
#  'short_model_750',
#  'short_model_750i',
#  'short_model_750xi',
#  'short_model_86',
#  'short_model_911',
#  'short_model_914',
#  'short_model_928',
#  'short_model_944',
#  'short_model_ACURA*',
#  'short_model_ALL',
#  'short_model_AMC',
#  'short_model_ASC',
#  'short_model_Acuarea',
#  'short_model_American',
#  'short_model_Bentley',
#  'short_model_Blue',
#  'short_model_Buicks',
#  'short_model_C',
#  'short_model_CHEVORLET',
#  'short_model_Champion',
#  'short_model_Chevey',
#  'short_model_Comanche',
#  'short_model_Comet',
#  'short_model_D7FH173552',
#  'short_model_DODGE1500',
#  'short_model_Diahatsu',
#  'short_model_E46',
#  'short_model_EASY',
#  'short_model_Eagle',
#  'short_model_Emergency',
#  'short_model_F-250',
#  'short_model_F250',
#  'short_model_FORD*',
#  'short_model_FORD/RANGER',
#  'short_model_FREIGHTLINER',
#  'short_model_FRRV',
#  'short_model_Flexible',
#  'short_model_FordE350',
#  'short_model_Freightliner',
#  'short_model_Frtlner',
#  'short_model_GCM',
#  'short_model_GEHL',
#  'short_model_GMC,',
#  'short_model_GMX',
#  'short_model_GRAND',
#  'short_model_GULF',
#  'short_model_Genesis',
#  'short_model_Gx',
#  'short_model_HINO',
#  'short_model_Hino',
#  'short_model_Hobda',
#  'short_model_Hot',
#  'short_model_Hummer',
#  'short_model_IC',
#  'short_model_INTERNATIONAL',
#  'short_model_International',
#  'short_model_Isizu',
#  'short_model_Isuzu',
#  'short_model_JM1BK32F871604924',
#  'short_model_Janesville',
#  'short_model_Jauguar',
#  'short_model_Jayco',
#  'short_model_Kaiser',
#  'short_model_Lotus',
#  'short_model_MASERATI',
#  'short_model_MERCUTY',
#  'short_model_MERDECES',
#  'short_model_MGB',
#  'short_model_MITUSBISHI',
#  'short_model_MV-1',
#  'short_model_Maserati',
#  'short_model_Minin',
#  'short_model_Nascar',
#  'short_model_OLDSMOBILE',
#  'short_model_PLYMOUTH',
#  'short_model_Peterbilt',
#  'short_model_Pierce',
#  'short_model_Plymouth',
#  'short_model_QX',
#  'short_model_S60',
#  'short_model_SCION',
#  'short_model_Saab',
#  'short_model_Sea',
#  'short_model_Sterling',
#  'short_model_Studebaker',
#  'short_model_Suzuki',
#  'short_model_THOMAS',
#  'short_model_Thomas',
#  'short_model_Town',
#  'short_model_Triumph',
#  'short_model_Voltswagon',
#  'short_model_Xx',
#  'short_model_a-class',
#  'short_model_a3',
#  'short_model_a3,',
#  'short_model_a5',
#  'short_model_a6',
#  'short_model_a7',
#  'short_model_a8',
#  'short_model_acadia',
#  'short_model_accent',
#  'short_model_all',
#  'short_model_allante',
#  'short_model_allroad',
#  'short_model_am',
#  'short_model_amc',
#  'short_model_arcadia',
#  'short_model_armada',
#  'short_model_arteon',
#  'short_model_ascent',
#  'short_model_aspen',
#  'short_model_astra',
#  'short_model_astro',
#  'short_model_atlas',
#  'short_model_ats',
#  'short_model_aura',
#  'short_model_autobiography',
#  'short_model_avanger',
#  'short_model_avenger',
#  'short_model_aveo',
#  'short_model_aviator',
#  'short_model_azera',
#  'short_model_aztek',
#  'short_model_b-class',
#  'short_model_b-series',
#  'short_model_b2200',
#  'short_model_b2300',
#  'short_model_b2600i',
#  'short_model_baja',
#  'short_model_beetle',
#  'short_model_bel',
#  'short_model_belair',
#  'short_model_benz',
#  'short_model_blackwood',
#  'short_model_blazer',
#  'short_model_blue',
#  'short_model_bolt',
#  'short_model_bonanza',
#  'short_model_bonneville',
#  'short_model_boxster',
#  'short_model_bronco',
#  'short_model_brz',
#  'short_model_bug',
#  'short_model_bus',
#  'short_model_c',
#  'short_model_c-10',
#  'short_model_c-7500',
#  'short_model_c-class',
#  'short_model_c-max',
#  'short_model_c/k',
#  'short_model_c10',
#  'short_model_c250',
#  'short_model_c280',
#  'short_model_c30',
#  'short_model_c300',
#  'short_model_c4500',
#  'short_model_c5500',
#  'short_model_c60',
#  'short_model_c6500',
#  'short_model_c70',
#  'short_model_c8500',
#  'short_model_cabellero',
#  'short_model_cabrio',
#  'short_model_caddilac',
#  'short_model_cadenza',
#  'short_model_caliber',
#  'short_model_camary',
#  'short_model_camero',
#  'short_model_canyon',
#  'short_model_capri',
#  'short_model_caprice',
#  'short_model_captiva',
#  'short_model_caravan',
#  'short_model_caravan/grand',
#  'short_model_cargo',
#  'short_model_cascada',
#  'short_model_cavalier',
#  'short_model_cayenne',
#  'short_model_cayman',
#  'short_model_cc',
#  'short_model_cc300',
#  'short_model_cc4500',
#  'short_model_century',
#  'short_model_certified',
#  'short_model_cherokee',
#  'short_model_chevelle',
#  'short_model_chevorlet',
#  'short_model_chryler',
#  'short_model_chysler',
#  'short_model_city',
#  'short_model_cj-5',
#  'short_model_cj2a',
#  'short_model_cj5',
#  'short_model_cj7',
#  'short_model_cj8',
#  'short_model_cl-class',
#  'short_model_cla',
#  'short_model_cla-class',
#  'short_model_clarity',
#  'short_model_classic',
#  'short_model_classuc',
#  'short_model_clk',
#  'short_model_clk-class',
#  'short_model_clk350',
#  'short_model_cls-class',
#  'short_model_cls550',
#  'short_model_clubman',
#  'short_model_cmax',
#  'short_model_colbalt',
#  'short_model_comet',
#  'short_model_commander',
#  'short_model_compass',
#  'short_model_concorde',
#  'short_model_conquest',
#  'short_model_continental',
#  'short_model_convertible',
#  'short_model_corsair',
#  'short_model_cougar',
#  'short_model_country',
#  'short_model_countryman',
#  'short_model_coupe',
#  'short_model_crew',
#  'short_model_crossfire',
#  'short_model_crosstour',
#  'short_model_crosstrek',
#  'short_model_crown',
#  'short_model_crv',
#  'short_model_crz',
#  'short_model_ct',
#  'short_model_ct4',
#  'short_model_ct5',
#  'short_model_ct6',
#  'short_model_cts',
#  'short_model_cts-v',
#  'short_model_cts4',
#  'short_model_cube',
#  'short_model_cvr',
#  'short_model_cx-3',
#  'short_model_cx-7',
#  'short_model_cx-9',
#  'short_model_cx7',
#  'short_model_cx9',
#  'short_model_d50',
#  'short_model_dakota',
#  'short_model_davidson',
#  'short_model_dealer*',
#  'short_model_defender',
#  'short_model_deisel',
#  'short_model_deluxe',
#  'short_model_denali',
#  'short_model_deville',
#  'short_model_diesel',
#  'short_model_discovery',
#  'short_model_dts',
#  'short_model_dump',
#  'short_model_duramax',
#  'short_model_durangon',
#  'short_model_e',
#  'short_model_e-150',
#  'short_model_e-250',
#  'short_model_e-450',
#  'short_model_e-class',
#  'short_model_e-pace',
#  'short_model_e150',
#  'short_model_e250',
#  'short_model_e320',
#  'short_model_e46',
#  'short_model_e500',
#  'short_model_echo',
#  'short_model_eclipse',
#  'short_model_econoline',
#  'short_model_ecosport',
#  'short_model_el',
#  'short_model_elcamino',
#  'short_model_eldorado',
#  'short_model_element',
#  'short_model_endeavor',
#  'short_model_envision',
#  'short_model_envoy',
#  'short_model_eqinox',
#  'short_model_es300',
#  'short_model_es330',
#  'short_model_es350',
#  'short_model_escape-se,',
#  'short_model_escort',
#  'short_model_expedition',
#  'short_model_f',
#  'short_model_f-100',
#  'short_model_f-350sd',
#  'short_model_f-450',
#  'short_model_f-450sd',
#  'short_model_f-550',
#  'short_model_f-650',
#  'short_model_f-750',
#  'short_model_f-pace',
#  'short_model_f1',
#  'short_model_f100',
#  'short_model_f350',
#  'short_model_f450',
#  'short_model_f450sd',
#  'short_model_f50',
#  'short_model_f550',
#  'short_model_f600',
#  'short_model_f700',
#  'short_model_f750',
#  'short_model_falcon',
#  'short_model_fe',
#  'short_model_fiero',
#  'short_model_firebird',
#  'short_model_five',
#  'short_model_fj40',
#  'short_model_fleetmaster',
#  'short_model_fleetwood',
#  'short_model_flex',
#  'short_model_fords',
#  'short_model_forester',
#  'short_model_forte5',
#  'short_model_foxbody',
#  'short_model_freestar',
#  'short_model_freightliner',
#  'short_model_frontier',
#  'short_model_fuso',
#  'short_model_fx35',
#  'short_model_fx45',
#  'short_model_g-class',
#  'short_model_g.',
#  'short_model_g20',
#  'short_model_g30',
#  'short_model_g35',
#  'short_model_g35x',
#  'short_model_g37s',
#  'short_model_g37x',
#  'short_model_g4500',
#  'short_model_g5',
#  'short_model_g6',
#  'short_model_g8',
#  'short_model_galant',
#  'short_model_ghia',
#  'short_model_gl',
#  'short_model_gl-class',
#  'short_model_gl450',
#  'short_model_gla',
#  'short_model_gladiator',
#  'short_model_glc',
#  'short_model_glc-class',
#  'short_model_gle',
#  'short_model_gle-class',
#  'short_model_glk',
#  'short_model_glk-class',
#  'short_model_glk350',
#  'short_model_gls',
#  'short_model_gmc/chev',
#  'short_model_gmce',
#  'short_model_gmt-400',
#  'short_model_gr',
#  'short_model_grandville',
#  'short_model_grumman',
#  'short_model_gs',
#  'short_model_gs350',
#  'short_model_gs430',
#  'short_model_gt',
#  'short_model_gt-r',
#  'short_model_gti',
#  'short_model_gx460',
#  'short_model_gx470',
#  'short_model_hardbody',
#  'short_model_hardtop',
#  'short_model_hearse',
#  'short_model_hhr',
#  'short_model_hiace',
#  'short_model_high',
#  'short_model_hr-v',
#  'short_model_hse',
#  'short_model_hyndai',
#  'short_model_i-miev',
#  'short_model_i30',
#  'short_model_i35',
#  'short_model_impreza',
#  'short_model_insight',
#  'short_model_international',
#  'short_model_ion',
#  'short_model_ioniq',
#  'short_model_is',
#  'short_model_is300',
#  'short_model_isuzu',
#  'short_model_jeepster',
#  'short_model_jimmy',
#  'short_model_jouney',
#  'short_model_journey',
#  'short_model_jx35',
#  'short_model_k10',
#  'short_model_k20',
#  'short_model_k30',
#  'short_model_k5',
#  'short_model_kicks',
#  'short_model_kodiak',
#  'short_model_l',
#  'short_model_l300',
#  'short_model_lancer',
#  'short_model_landcruiser',
#  'short_model_legacy',
#  'short_model_legend',
#  'short_model_lemans',
#  'short_model_lesabre',
#  'short_model_lifted',
#  'short_model_lightning',
#  'short_model_limousine',
#  'short_model_long',
#  'short_model_lr2',
#  'short_model_lr3',
#  'short_model_ls',
#  'short_model_ltd',
#  'short_model_lucerne',
#  'short_model_lx',
#  'short_model_m',
#  'short_model_m-class',
#  'short_model_m35',
#  'short_model_m5',
#  'short_model_macan',
#  'short_model_magnum',
#  'short_model_mallinia',
#  'short_model_marineer,premier',
#  'short_model_mariner',
#  'short_model_mark',
#  'short_model_maserati',
#  'short_model_matrix',
#  'short_model_maximum',
#  'short_model_mazda2',
#  'short_model_mazda5',
#  'short_model_mazda6',
#  'short_model_mazda6i',
#  'short_model_md-x',
#  'short_model_mercades',
#  'short_model_mercedes-amg',
#  'short_model_metris',
#  'short_model_mg',
#  'short_model_miata',
#  'short_model_milan',
#  'short_model_mkc',
#  'short_model_mks',
#  'short_model_mkt',
#  'short_model_ml',
#  'short_model_ml350',
#  'short_model_ml500',
#  'short_model_model',
#  'short_model_monte',
#  'short_model_montero',
#  'short_model_mountaineer',
#  'short_model_mpv',
#  'short_model_mr2',
#  'short_model_mx-5',
#  'short_model_nautilus',
#  'short_model_navigator',
#  'short_model_neon',
#  'short_model_new',
#  'short_model_newport',
#  'short_model_niro',
#  'short_model_nv',
#  'short_model_nv1500',
#  'short_model_nv200',
#  'short_model_nv2500',
#  'short_model_nv2500hd',
#  'short_model_nx',
#  'short_model_nx300',
#  'short_model_oddyssey',
#  'short_model_oldsmobile',
#  'short_model_optima',
#  'short_model_optimia',
#  'short_model_outback',
#  'short_model_outlook',
#  'short_model_paceman',
#  'short_model_pacifica',
#  'short_model_panamera',
#  'short_model_panel',
#  'short_model_park',
#  'short_model_passat',
#  'short_model_passport',
#  'short_model_pathfinder',
#  'short_model_patriot',
#  'short_model_phaeton',
#  'short_model_pick',
#  'short_model_pickup',
#  'short_model_pontaic',
#  'short_model_prelude',
#  'short_model_prizm',
#  'short_model_protege',
#  'short_model_pt',
#  'short_model_putback',
#  'short_model_q3',
#  'short_model_q5',
#  'short_model_q50',
#  'short_model_q60',
#  'short_model_q70',
#  'short_model_quattro',
#  'short_model_quest',
#  'short_model_qx50',
#  'short_model_qx56',
#  'short_model_qx60',
#  'short_model_qx70',
#  'short_model_r-class',
#  'short_model_r32',
#  'short_model_rabbit',
#  'short_model_rainier',
#  'short_model_ram1500',
#  'short_model_ram2500',
#  'short_model_ramcharger',
#  'short_model_range',
#  'short_model_ranger',
#  'short_model_rat',
#  'short_model_rav',
#  'short_model_rc',
#  'short_model_rdx',
#  'short_model_reatta',
#  'short_model_rebel',
#  'short_model_rendezvous',
#  'short_model_replica',
#  'short_model_ridgeline',
#  'short_model_rio',
#  'short_model_rivera',
#  'short_model_riviera',
#  'short_model_rl',
#  'short_model_rlx',
#  'short_model_roadmaster',
#  'short_model_roadster',
#  'short_model_romeo',
#  'short_model_rondo',
#  'short_model_rouge',
#  'short_model_routan',
#  'short_model_rs',
#  'short_model_rsx',
#  'short_model_rx-8',
#  'short_model_rx300',
#  'short_model_rx330',
#  'short_model_rx350',
#  'short_model_rx400h',
#  'short_model_rx7',
#  'short_model_rx8',
#  'short_model_s',
#  'short_model_s-10',
#  'short_model_s/w',
#  'short_model_s10',
#  'short_model_s2000',
#  'short_model_s3',
#  'short_model_s320',
#  'short_model_s4',
#  'short_model_s40',
#  'short_model_s430',
#  'short_model_s5',
#  'short_model_s500',
#  'short_model_s6',
#  'short_model_s60',
#  'short_model_s7',
#  'short_model_s70',
#  'short_model_s8',
#  'short_model_s90',
#  'short_model_saab',
#  'short_model_sable',
#  'short_model_sante',
#  'short_model_savana',
#  'short_model_sc',
#  'short_model_sc2',
#  'short_model_sc300',
#  'short_model_school',
#  'short_model_scion',
#  'short_model_sebring',
#  'short_model_sedan',
#  'short_model_seirra',
#  'short_model_sequioa',
#  'short_model_sequoia',
#  'short_model_seville',
#  'short_model_shelby',
#  'short_model_sierra1500',
#  'short_model_sky',
#  'short_model_skylark',
#  'short_model_sl-class',
#  'short_model_sl2',
#  'short_model_sl500',
#  'short_model_sl55',
#  'short_model_sl550',
#  'short_model_slc',
#  'short_model_sle',
#  'short_model_slk',
#  'short_model_slk-class',
#  'short_model_slt',
#  'short_model_smart',
#  'short_model_solara',
#  'short_model_solstice',
#  'short_model_sonata',
#  'short_model_sonoma',
#  'short_model_sorrento',
#  'short_model_soul',
#  'short_model_soul+',
#  'short_model_spectra',
#  'short_model_sprinter',
#  'short_model_srx',
#  'short_model_srx-v6',
#  'short_model_srx4',
#  'short_model_srx~awesome',
#  'short_model_ss',
#  'short_model_ssr',
#  'short_model_starcraft',
#  'short_model_step-van',
#  'short_model_stinger',
#  'short_model_stratus',
#  'short_model_sts',
#  'short_model_studebaker',
#  'short_model_suburban',
#  'short_model_supra',
#  'short_model_suv',
#  'short_model_suzuki',
#  'short_model_svx',
#  'short_model_t',
#  'short_model_t-350',
#  'short_model_t-bucket',
#  'short_model_tarsus',
#  'short_model_tc5500',
#  'short_model_telluride',
#  'short_model_tercel',
#  'short_model_terrain',
#  'short_model_thing',
#  'short_model_thomas',
#  'short_model_thrift',
#  'short_model_thunderbird',
#  'short_model_tl',
#  'short_model_tlx',
#  'short_model_torrent',
#  'short_model_touareg',
#  'short_model_tracker',
#  'short_model_tractor',
#  'short_model_trailblazer',
#  'short_model_trans',
#  'short_model_traverse',
#  'short_model_tribeca',
#  'short_model_tribute',
#  'short_model_triumph',
#  'short_model_truck',
#  'short_model_tsx',
#  'short_model_tt',
#  'short_model_tucson',
#  'short_model_tudor',
#  'short_model_uplander',
#  'short_model_utility',
#  'short_model_ux',
#  'short_model_v50',
#  'short_model_v6',
#  'short_model_v60',
#  'short_model_v90',
#  'short_model_van',
#  'short_model_vanagon',
#  'short_model_vandura',
#  'short_model_velar',
#  'short_model_veloster',
#  'short_model_venture',
#  'short_model_venza',
#  'short_model_veracruz',
#  'short_model_vibe',
#  'short_model_villager',
#  'short_model_vnl',
#  'short_model_volt',
#  'short_model_voyager',
#  'short_model_vtx1300c',
#  'short_model_vue',
#  'short_model_w350',
#  'short_model_willys',
#  'short_model_windstar',
#  'short_model_wrx',
#  'short_model_x-3',
#  'short_model_x-type',
#  'short_model_x1',
#  'short_model_x2',
#  'short_model_x3',
#  'short_model_x4',
#  'short_model_xc',
#  'short_model_xc40',
#  'short_model_xc60',
#  'short_model_xc70',
#  'short_model_xe',
#  'short_model_xf',
#  'short_model_xj',
#  'short_model_xj-series',
#  'short_model_xj8',
#  'short_model_xk8',
#  'short_model_xt4',
#  'short_model_xt5',
#  'short_model_xt6',
#  'short_model_xterra',
#  'short_model_xts',
#  'short_model_yukon',
#  'short_model_z',
#  'short_model_z3',
#  'short_model_z4',
#  'short_model_zephyr',
#  'short_model_zx2',
#  'region_albuquerque',
#  'region_altoona-johnstown',
#  'region_ames',
#  'region_ann arbor',
#  'region_annapolis',
#  'region_appleton-oshkosh-FDL',
#  'region_ashtabula',
#  'region_athens',
#  'region_atlanta',
#  'region_auburn',
#  'region_augusta',
#  'region_austin',
#  'region_bakersfield',
#  'region_baltimore',
#  'region_baton rouge',
#  'region_beaumont / port arthur',
#  'region_bellingham',
#  'region_bemidji',
#  'region_binghamton',
#  'region_bismarck',
#  'region_bloomington',
#  'region_bloomington-normal',
#  'region_boone',
#  'region_boston',
#  'region_bowling green',
#  'region_bozeman',
#  'region_brainerd',
#  'region_brownsville',
#  'region_brunswick',
#  'region_butte',
#  'region_cape cod / islands',
#  'region_catskills',
#  'region_cedar rapids',
#  'region_central louisiana',
#  'region_champaign urbana',
#  'region_charleston',
#  'region_charlottesville',
#  'region_chattanooga',
#  'region_chautauqua',
#  'region_chillicothe',
#  'region_cincinnati',
#  'region_cleveland',
#  'region_clovis / portales',
#  'region_college station',
#  'region_columbia',
#  'region_columbia / jeff city',
#  'region_cumberland valley',
#  'region_dayton / springfield',
#  'region_daytona beach',
#  'region_decatur',
#  'region_del rio / eagle pass',
#  'region_delaware',
#  'region_denver',
#  'region_dothan',
#  'region_dubuque',
#  'region_duluth / superior',
#  'region_east idaho',
#  'region_east oregon',
#  'region_eastern CO',
#  'region_eastern CT',
#  'region_eastern kentucky',
#  'region_eastern montana',
#  'region_eastern panhandle',
#  'region_eastern shore',
#  'region_eau claire',
#  'region_el paso',
#  'region_elko',
#  'region_elmira-corning',
#  'region_erie',
#  'region_evansville',
#  'region_fairbanks',
#  'region_fargo / moorhead',
#  'region_farmington',
#  'region_fayetteville',
#  'region_finger lakes',
#  'region_flagstaff / sedona',
#  'region_florence',
#  'region_florence / muscle shoals',
#  'region_fort dodge',
#  'region_fort smith',
#  'region_fort wayne',
#  'region_frederick',
#  'region_ft myers / SW florida',
#  'region_gadsden-anniston',
#  'region_gainesville',
#  'region_galveston',
#  'region_glens falls',
#  'region_grand forks',
#  'region_grand island',
#  'region_grand rapids',
#  'region_great falls',
#  'region_greensboro',
#  'region_greenville / upstate',
#  'region_gulfport / biloxi',
#  'region_hanford-corcoran',
#  'region_harrisburg',
#  'region_harrisonburg',
#  'region_hartford',
#  'region_hattiesburg',
#  'region_hawaii',
#  'region_heartland florida',
#  'region_helena',
#  'region_hickory / lenoir',
#  'region_high rockies',
#  'region_hilton head',
#  'region_holland',
#  'region_houma',
#  'region_hudson valley',
#  'region_humboldt county',
#  'region_huntington-ashland',
#  'region_huntsville / decatur',
#  'region_imperial county',
#  'region_indianapolis',
#  'region_iowa city',
#  'region_ithaca',
#  'region_jackson',
#  'region_janesville',
#  'region_jersey shore',
#  'region_jonesboro',
#  'region_joplin',
#  'region_kalamazoo',
#  'region_kenai peninsula',
#  'region_kennewick-pasco-richland',
#  'region_kenosha-racine',
#  'region_killeen / temple / ft hood',
#  'region_kirksville',
#  'region_klamath falls',
#  'region_kokomo',
#  'region_la salle co',
#  'region_lafayette',
#  'region_lafayette / west lafayette',
#  'region_lake charles',
#  'region_lake of the ozarks',
#  'region_lancaster',
#  'region_las cruces',
#  'region_las vegas',
#  'region_lawton',
#  'region_lehigh valley',
#  'region_lewiston / clarkston',
#  'region_lima / findlay',
#  'region_lincoln',
#  'region_logan',
#  'region_long island',
#  'region_louisville',
#  'region_lubbock',
#  'region_lynchburg',
#  'region_macon / warner robins',
#  'region_manhattan',
#  'region_mankato',
#  'region_mansfield',
#  'region_mason city',
#  'region_mattoon-charleston',
#  'region_mcallen / edinburg',
#  'region_meadville',
#  'region_medford-ashland',
#  'region_mendocino county',
#  'region_merced',
#  'region_milwaukee',
#  'region_mobile',
#  'region_mohave county',
#  'region_monroe',
#  'region_montgomery',
#  'region_morgantown',
#  'region_moses lake',
#  'region_muncie / anderson',
#  'region_muskegon',
#  'region_myrtle beach',
#  'region_new haven',
#  'region_new orleans',
#  'region_new river valley',
#  'region_new york city',
#  'region_north central FL',
#  'region_north dakota',
#  'region_north jersey',
#  'region_north platte',
#  'region_northeast SD',
#  'region_northern WI',
#  'region_northern michigan',
#  'region_northern panhandle',
#  'region_northwest CT',
#  'region_northwest GA',
#  'region_northwest KS',
#  'region_northwest OK',
#  'region_ocala',
#  'region_odessa / midland',
#  'region_ogden-clearfield',
#  'region_okaloosa / walton',
#  'region_oneonta',
#  'region_orange county',
#  'region_oregon coast',
#  'region_outer banks',
#  'region_owensboro',
#  'region_panama city',
#  'region_parkersburg-marietta',
#  'region_pensacola',
#  'region_peoria',
#  'region_pierre / central SD',
#  'region_pittsburgh',
#  'region_plattsburgh-adirondacks',
#  'region_poconos',
#  'region_port huron',
#  'region_potsdam-canton-massena',
#  'region_pullman / moscow',
#  'region_quad cities, IA/IL',
#  'region_reading',
#  'region_rhode island',
#  'region_richmond',
#  'region_rockford',
#  'region_roseburg',
#  'region_roswell / carlsbad',
#  'region_salina',
#  'region_salt lake city',
#  ...]

# %%
df_prepared = df.drop(to_drop_f_imp_list, axis=1)
df_prepared
# Out:
#               id  price price_category  is_audi  is_ford  is_chevrolet  \
# 0     7308295377  54990           high        0        0             0
# 1     7316380095  16942         medium        0        1             0
# 2     7313733749  35590           high        0        0             0
# 3     7308210929  14500         medium        0        0             0
# 4     7303797340  14590         medium        0        0             0
# ...          ...    ...            ...      ...      ...           ...
# 9614  7304876387   4495            low        0        0             0
# 9615  7316152972  14495         medium        0        0             0
# 9616  7310993818   8995            low        1        0             0
# 9617  7306637427  31900           high        0        0             0
# 9618  7311960763  31990           high        0        0             0
#
#       is_toyota  x0_diesel  x0_electric  x0_gas  ...  long_std  year_std  \
# 0             0        1.0          0.0     0.0  ...  0.484245  1.322394
# 1             0        0.0          0.0     0.0  ...  1.110800  0.695973
# 2             0        0.0          0.0     1.0  ...  0.531185  0.852578
# 3             1        0.0          0.0     1.0  ...  0.853562  0.226157
# 4             0        0.0          0.0     0.0  ...  0.557607  0.069552
# ...         ...        ...          ...     ...  ...       ...       ...
# 9614          1        0.0          0.0     1.0  ...  0.823646 -1.496501
# 9615          0        0.0          0.0     1.0  ...  0.903947 -0.556869
# 9616          0        0.0          0.0     1.0  ... -1.628875 -0.087054
# 9617          0        0.0          0.0     0.0  ...  0.251959  0.539367
# 9618          0        0.0          0.0     1.0  ...  0.985465  0.852578
#
#       odometer/price_std  desc_len_std  model_in_desc_std  model_len_std  \
# 0              -0.510784      0.632075          -0.155788       1.163032
# 1              -0.402947     -0.646781          -0.155788       0.932087
# 2              -0.514480      0.560744          -0.155788       0.470197
# 3              -0.241883      0.180435          -0.155788      -0.915473
# 4              -0.333074      0.766366          -0.155788       1.163032
# ...                  ...           ...                ...            ...
# 9614            0.653795     -0.376744          -0.155788      -0.915473
# 9615           -0.250872     -0.654060          -0.155788      -0.453583
# 9616            0.063061     -0.668253          -0.155788       1.509450
# 9617           -0.459670      0.327100          -0.155788      -0.569055
# 9618           -0.488682      0.632439          -0.155788       1.163032
#
#       model_word_count_std  month_std  dayofweek_std  diff_years_std
# 0                 1.910669  -0.615846       1.120284       -1.322394
# 1                 1.235799   1.623784      -1.374972       -0.695973
# 2                 0.560930  -0.615846      -0.376870       -0.852578
# 3                -0.788810  -0.615846       1.120284       -0.226157
# 4                 1.910669  -0.615846       0.122182       -0.069552
# ...                    ...        ...            ...             ...
# 9614             -0.788810  -0.615846       1.120284        1.496501
# 9615             -0.788810   1.623784      -1.374972        0.556869
# 9616              1.910669  -0.615846       0.122182        0.087054
# 9617             -0.788810  -0.615846      -0.376870       -0.539367
# 9618              1.910669  -0.615846       1.120284       -0.852578
#
# [9619 rows x 369 columns]

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_test, predicted_test))
# Out:
# 0.668052668052668

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[742,  56, 199],
#        [ 44, 676, 233],
#        [187, 239, 510]], dtype=int64)

# %% [markdown]
# 2. Подготовка модели случайного леса
#
# Обучите простую модель классификации с помощью RandomForestClassifier. Для этого на новых урезанных семплах тренировочной и тестовой выборок обучите модель случайного леса с зафиксированным random_state=50.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Ваш код здесь 
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=50
)

# %%
rt_clf = RandomForestClassifier()
rt_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# 2. Сделайте предикт, посчитайте точность модели и матрицу ошибок. Сравните с предыдущей моделью дерева решений. Есть ли случаи, когда модель из пункта 1 отрабатывает лучше, чем модель случайного леса?

# %%
# Ваш код здесь 
predicted_train_rt = rt_clf.predict(x_train)
predicted_test_rt = rt_clf.predict(x_test)

print(accuracy_score(y_train, predicted_train_rt))
print(accuracy_score(y_test, predicted_test_rt))
# Out:
# 1.0
# 0.7571032571032571

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[299, 323, 324],
#        [334, 345, 296],
#        [340, 303, 322]], dtype=int64)

# %% [markdown]
# 3. Тюнинг модели случайного леса
#
# Увеличьте точность модели на тестовом датасете RandomForestClassifier c помощью тюнинга параметров.
#
# Параметры, которые можно настраивать для увеличения точности:
# ```
#     `bootstrap'
#     'max_depth'
#     'max_features'
#     'min_samples_leaf'
#     'min_samples_split'
#     'random_state'
#     'n_estimators'
#
# ```
#
# С описанием каждого из параметров можно ознакомиться [в документации](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html).
#
# Задание засчитывается, если значение метрики строго выше 0.76 на тестовом датасете.

# %%
# Ваш код здесь 
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=50
)

# %%
params = {
    'n_estimators': 500,
    'max_depth': 65,
    'min_samples_split': 6,
    'min_samples_leaf': 1,
    'max_features': 'log2',
    'bootstrap': False,
    'random_state': 42
}

# %%
rt_clf = RandomForestClassifier(**params)
rt_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=65, max_features='log2',
#                        min_samples_split=6, n_estimators=500, random_state=42)

# %%
predicted_train_rt = rt_clf.predict(x_train)
predicted_test_rt = rt_clf.predict(x_test)

print(accuracy_score(y_train, predicted_train_rt))
print(accuracy_score(y_test, predicted_test_rt))
# Out:
# 0.9901975345314125
# 0.761954261954262

# %% [markdown]
# 4. Анализ влияния фичей на модель
#
# До этого в задачах вы работали над подготовленным датасетом, где фичи были заранее извлечены из текстовых переменных, отскейлены и пропущены через OneHotEncoder. Сравним, какой была бы предсказательная способность модели, если бы мы использовали только сырые данные из исходного датасета. Для этого проделайте следующие шаги:
#
# 1. Загрузите датасет `vehicles_dataset_old.csv`.
# 2. Удалите из него переменную `price` и все строковые колонки. Дерево решений и случайный лес не умеют самостоятельно работать со строковыми значениями.
# 3. Сформируйте x_train и x_test так же, как они были сформированы в предыдущих заданиях.
# 4. Обучите свою лучшую модель случайного леса на новых данных и замерьте качество. Убедитесь, что оно ухудшилось.
# 5. Найдите три фичи, которые лучшим образом повлияли на предсказательную способность модели.

# %%
df_old = pd.read_csv('data/vehicles_dataset_old.csv')
df_old.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7303797340  https://knoxville.craigslist.org/ctd/d/knoxvil...
#
#          region                           region_url  price  year  \
# 0   chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1  north jersey     https://newjersey.craigslist.org  16942  2016
# 2  reno / tahoe          https://reno.craigslist.org  35590  2017
# 3  fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4     knoxville     https://knoxville.craigslist.org  14590  2012
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# 1         ford    explorer 4wd 4dr xlt   other     60023        clean
# 2   volkswagen        golf r hatchback     gas     14048        clean
# 3       toyota                    rav4     gas    117291        clean
# 4          bmw  1 series 128i coupe 2d   other     80465        clean
#
#   transmission                                          image_url  \
# 0        other  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 1    automatic  https://images.craigslist.org/00x0x_26jl9F0cnL...
# 2        other  https://images.craigslist.org/00y0y_eeZjWeiSfb...
# 3    automatic  https://images.craigslist.org/00606_iGe5iXidib...
# 4        other  https://images.craigslist.org/00F0F_5UAXmOzC18...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    tn  35.060000
# 1  ***Call Us for more information at: 201-635-14...    nj  40.821805
# 2  Carvana is the safer way to buy a car During t...    ca  33.779214
# 3  2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...    nc  35.715954
# 4  Carvana is the safer way to buy a car During t...    tn  35.970000
#
#         long              posting_date price_category  \
# 0 -85.250000  2021-04-17T12:30:50-0400           high
# 1 -74.061962  2021-05-03T15:40:21-0400         medium
# 2 -84.411811  2021-04-28T03:52:20-0700           high
# 3 -78.655304  2021-04-17T10:08:57-0400         medium
# 4 -83.940000  2021-04-08T15:10:56-0400         medium
#
#                         date
# 0  2021-04-17 16:30:50+00:00
# 1  2021-05-03 19:40:21+00:00
# 2  2021-04-28 10:52:20+00:00
# 3  2021-04-17 14:08:57+00:00
# 4  2021-04-08 19:10:56+00:00

# %%
# Ваш код здесь 
df_old.drop(columns=['price'], inplace=True)

# %%
to_drop = [column for column in df_old.columns if column != 'price_category' and df_old[column].dtype == object]

if to_drop:
    df_old.drop(to_drop, axis=1, inplace=True)

# %%
print(df_old.head())
# Out:
#            id  year  odometer        lat       long price_category
# 0  7308295377  2020     27442  35.060000 -85.250000           high
# 1  7316380095  2016     60023  40.821805 -74.061962         medium
# 2  7313733749  2017     14048  33.779214 -84.411811           high
# 3  7308210929  2013    117291  35.715954 -78.655304         medium
# 4  7303797340  2012     80465  35.970000 -83.940000         medium

# %%
x = df_old.drop(['price_category'], axis=1)
y = df_old['price_category']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

# %%
params = {
    'n_estimators': 500,
    'max_depth': 65,
    'min_samples_split': 6,
    'min_samples_leaf': 1,
    'max_features': 'log2',
    'bootstrap': False,
    'random_state': 42
}

# %%
rt_clf = RandomForestClassifier(**params)
rt_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=65, max_features='log2',
#                        min_samples_split=6, n_estimators=500, random_state=42)

# %%
predicted_train_rt = rt_clf.predict(x_train)
predicted_test_rt = rt_clf.predict(x_test)

print(accuracy_score(y_train, predicted_train_rt))
print(accuracy_score(y_test, predicted_test_rt))
# Out:
# 0.9998514777959305
# 0.6337491337491338

# %%
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)
f_imp_list[:3]
# Out:
# [('id', 0.032842640144256),
#  ('long', 0.0031420047595655774),
#  ('lat', 0.0023203778764949207)]
